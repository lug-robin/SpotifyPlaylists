# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np

# %%
df=pd.read_csv("Spotify_cleaned.csv",sep=",")

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.columns
# Out:
# Index(['user_id', 'artist', 'track', 'playlist'], dtype='object')

# %%
artist_no = df[['track','artist']].value_counts()

# %%
artist_no.head(15)
# Out:
# track                                                     artist
# Midnight City                                             M83                        2609
# Get Lucky - Radio Edit                                    Daft Punk                  2341
# Radioactive                                               Imagine Dragons            2336
# Little Talks                                              Of Monsters and Men        2254
# Wake Me Up                                                Avicii                     2242
# Royals                                                    Lorde                      2219
# Ho Hey                                                    The Lumineers              2180
# Can't Hold Us - feat. Ray Dalton                          Macklemore & Ryan Lewis    2066
# Pompeii                                                   Bastille                   2014
# Blurred Lines                                             Robin Thicke               1996
# ...

# %%
df['playlist'].value_counts().head(20)
# Out:
# playlist
# Starred                  1337085
# Liked from Radio          180083
# Favoritas de la radio      30425
# Rock                       30142
# 2014                       22680
# Christmas                  22281
# 2013                       20895
# Work                       18410
# Jazz                       18291
# Indie                      17859
# Classical                  16328
# everything                 16316
# Country                    15520
# New Playlist               15245
# Music                      14952
# Generos                    14877
# Rap                        14506
# Chill                      13117
# 2012                       13101
# iPhone                     13086
# Name: count, dtype: int64

# %%
df['playlist'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 12891680 entries, 0 to 12891679
# Series name: playlist
# Non-Null Count     Dtype
# --------------     -----
# 12890434 non-null  object
# dtypes: object(1)
# memory usage: 98.4+ MB

# %%
artist_no.head(15).plot(kind='barh')
# Out:
# <Axes: ylabel='track,artist'>

# %%
df.playlist.value_counts().head(15).plot(kind='bar')
# Out:
# <Axes: xlabel='playlist'>

# %%
playlists = df[df.playlist != "Starred"]
playlists = playlists[df.playlist != "Liked from Radio"]
playlists = playlists[df.playlist != "Favoritas de la radio"]
# Out:
# C:\Users\luger\AppData\Local\Temp\ipykernel_13648\1950744209.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   playlists = playlists[df.playlist != "Liked from Radio"]
# C:\Users\luger\AppData\Local\Temp\ipykernel_13648\1950744209.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   playlists = playlists[df.playlist != "Favoritas de la radio"]

# %%
playlists['playlist'].value_counts().head(50)
# Out:
# playlist
# Rock                           30142
# 2014                           22680
# Christmas                      22281
# 2013                           20895
# Work                           18410
# Jazz                           18291
# Indie                          17859
# Classical                      16328
# everything                     16316
# Country                        15520
# New Playlist                   15245
# Music                          14952
# Generos                        14877
# Rap                            14506
# Chill                          13117
# 2012                           13101
# iPhone                         13086
# 2015                           11185
# Metal                          11180
# All Live Files                 11002
# My Shazam Tracks               10956
# Vitamin String Quartet         10717
# CHILL                          10552
# Random                         10535
# Pop                            10455
# ...

# %%
playlists['playlist'].value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='playlist'>

# %%
df['user_id'].value_counts().head(20)
# Out:
# user_id
# 4398de6902abde3351347b048fcdc287    295275
# 7ee2b92c5bcf6133b8132363e5bda960     90630
# 99deafd9b792af8e6a535483088faef2     65909
# fa849dabeb14a2800ad5130907fc5018     60713
# 6b85a8076b4f3b1036ef15f09e2feeeb     39669
# ed140fce438f59e6e07e5ee7bd726692     33197
# 2fa1f93e57cfe2f6c4456e98da54061c     31607
# c0efe4e704a37894150489b25eac9042     25960
# c410ee930bd5f0e4893632503ec17b05     25277
# c2d2fed26e858f82fdd8ac2e791cab1f     24855
# d49c0fdadc701f66d10aec118604f4b7     24711
# a9f844ceb4d928d7ff7c189211f301c5     22721
# 32b524ed367b1e5a714228fbec80849d     22202
# f2604a69836c94d00fcd11dd602944fc     20134
# c943688082716a65120321b4a0b15979     19710
# 61baddf7207fea410abdc56e680fa869     18898
# 68756b4d60b6fac27789e85c2b63d1c6     18857
# 95c206362d58124cad87e82b9c3652a6     18737
# 00123e0f544dee3ab006aa7f1e5725a7     18521
# ce7eab9cbb66a49a8b71c751458e8663     18320
# Name: count, dtype: int64

# %%
user_playlist = playlists[['user_id','playlist']].value_counts()

# %%
user_playlist.head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='user_id,playlist'>
